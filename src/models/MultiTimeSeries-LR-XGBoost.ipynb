# %%
# Importing required Libraries

import re
import nltk
import plotly
import itertools
import pandas as pd
import numpy as np
import colorlover as cl
import xgboost as xgb
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import seaborn as sns
import cufflinks as cf
import plotly.offline as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
cf.go_offline(connected=True)
from matplotlib import pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import TimeSeriesSplit
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from dateutil.relativedelta import relativedelta
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from sklearn import metrics
from sklearn import preprocessing
import statsmodels.api as sm

import warnings
warnings.filterwarnings('ignore')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# Importing the data

df_sales = pd.read_csv("/Users/satishreddychirra/Document/DS5500 Data Visualization/Sales_Multiseries.csv")

# %%
df_sales.head()
# Out:
#         Store      Date     Sales  Store_Size  Num_Employees  Returns_Pct  \
# 0  Louisville  07/01/12  76819.40       20100             42         1.03
# 1  Louisville  07/02/12  78963.86       20100             21         0.41
# 2  Louisville  07/03/12  74824.71       20100             26         0.31
# 3  Louisville  07/04/12  78523.92       20100             33         0.83
# 4  Louisville  07/05/12  76445.90       20100             38         0.51
#
#    Num_Customers  Pct_On_Sale  \
# 0            327         9.96
# 1            293         8.65
# 2            356         8.96
# 3            350        10.08
# 4            299         9.80
#
#                                            Marketing  Near_Xmas  \
# 0  July In Store Credit Card Signup Discount; In ...          0
# 1  July In Store Credit Card Signup Discount; In ...          0
# 2  July In Store Credit Card Signup Discount; In ...          0
# 3  July In Store Credit Card Signup Discount; In ...          0
# 4  July In Store Credit Card Signup Discount; ID5...          0
#
#    Near_BlackFriday Holiday DestinationEvent  Pct_Promotional  Econ_ChangeGDP  \
# 0                 0      No               No         0.000047             0.5
# 1                 0      No               No         0.000047             NaN
# 2                 0      No               No         0.000047             NaN
# 3                 0     Yes               No         0.000047             NaN
# 4                 0      No               No         0.000047             NaN
#
#    EconJobsChange  AnnualizedCPI
# 0             NaN           0.02
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7140 entries, 0 to 7139
# Data columns (total 17 columns):
# Store               7140 non-null object
# Date                7140 non-null object
# Sales               7140 non-null float64
# Store_Size          7140 non-null int64
# Num_Employees       7140 non-null int64
# Returns_Pct         7140 non-null float64
# Num_Customers       7140 non-null int64
# Pct_On_Sale         7130 non-null float64
# Marketing           7140 non-null object
# Near_Xmas           7140 non-null int64
# Near_BlackFriday    7140 non-null int64
# Holiday             7140 non-null object
# DestinationEvent    7140 non-null object
# Pct_Promotional     7140 non-null float64
# Econ_ChangeGDP      80 non-null float64
# EconJobsChange      1020 non-null float64
# AnnualizedCPI       240 non-null float64
# dtypes: float64(7), int64(5), object(5)
# memory usage: 948.4+ KB

# %%
df_sales.describe()
# Out:
#                Sales    Store_Size  Num_Employees  Returns_Pct  Num_Customers  \
# count    7140.000000   7140.000000    7140.000000  7140.000000    7140.000000
# mean    78534.278832  16910.000000      35.048739     0.769146     269.444258
# std     27445.616100   1927.023634      19.238847     0.469912     226.393313
# min         0.000000  13400.000000       0.000000     0.000000       0.000000
# 25%     61759.032500  15700.000000      23.000000     0.440000     154.000000
# 50%     70776.860000  16750.000000      31.000000     0.680000     207.000000
# 75%     85319.047500  18800.000000      41.000000     1.000000     287.000000
# max    324414.440000  20100.000000     214.000000     3.090000    2268.000000
#
#        Pct_On_Sale    Near_Xmas  Near_BlackFriday  Pct_Promotional  \
# count  7130.000000  7140.000000       7140.000000      7140.000000
# mean     11.711823     2.691877          0.179272         0.065318
# std       3.861841     6.958566          0.965183         0.033369
# min       0.000000     0.000000          0.000000        -0.001119
# 25%       8.940000     0.000000          0.000000         0.047338
# 50%      10.940000     0.000000          0.000000         0.058358
# 75%      13.717500     0.000000          0.000000         0.075387
# max      31.070000    31.000000          8.000000         0.163078
#
#        Econ_ChangeGDP  EconJobsChange  AnnualizedCPI
# count        80.00000     1020.000000     240.000000
# mean          1.76250     -590.686275       0.019447
# std           1.84661     5970.650044       0.025387
# min          -1.20000   -26000.000000      -0.034766
# 25%           0.40000    -4250.000000       0.009091
# 50%           1.80000     -250.000000       0.020241
# 75%           3.32500     3000.000000       0.028015
# max           4.00000    16500.000000       0.073502

# %%
# Extracting date columns

df_sales.Date = pd.to_datetime(df_sales.Date, format='%m/%d/%y')
df_sales['year'] = pd.DatetimeIndex(df_sales.Date).year
df_sales['month'] = pd.DatetimeIndex(df_sales.Date).month
df_sales['day'] = pd.DatetimeIndex(df_sales.Date).day
df_sales['dayOfWeek'] = pd.DatetimeIndex(df_sales.Date).dayofweek
df_sales['quarter'] = pd.DatetimeIndex(df_sales.Date).quarter
df_sales['dayOfYear'] = pd.DatetimeIndex(df_sales.Date).dayofyear
df_sales['weekOfYear'] = pd.DatetimeIndex(df_sales.Date).weekofyear

# %%
# Plotting the Number of Employees at the store over the time.

data = [dict(
  type = 'scatter',
  name = 'NumberOfEmployees',
  x = df_sales.Date,
  y = df_sales.Num_Employees,
  mode = 'markers+lines',
  transforms = [dict(
    type = 'groupby',
    groups = df_sales.Store
  )]
)]


layout = {
    'title': 'Number of Employees over the time',
    'yaxis': {'title': 'NumberOfEmployees'},
    'xaxis': {'title': 'Date'}
}


py.iplot({'data': data, 'layout': layout}, validate=False)
# Out:
# <div id="7da69e0c-7812-44be-ab92-fb8ca27d2dbd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7da69e0c-7812-44be-ab92-fb8ca27d2dbd", [{"type": "scatter", "name": "NumberOfEmployees", "x": ["2012-07-01", "2012-07-02", "2012-07-03", "2012-07-04", "2012-07-05", "2012-07-06", "2012-07-07", "2012-07-08", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-14", "2012-07-15", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-21", "2012-07-22", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-28", "2012-07-29", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-04", "2012-08-05", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-11", "2012-08-12", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-18", "2012-08-19", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-25", "2012-08-26", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-
013-01-05", "2013-01-06", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-12", "2013-01-13", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-19", "2013-01-20", "2013-01-21", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-26", "2013-01-27", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-02", "2013-02-03", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02-07", "2013-02-08", "2013-02-09", "2013-02-10", "2013-02-11", "2013-02-12", "2013-02-13", "2013-02-14", "2013-02-15", "2013-02-16", "2013-02-17", "2013-02-18", "2013-02-19", "2013-02-20", "2013-02-21", "2013-02-22", "2013-02-23", "2013-02-24", "2013-02-25", "2013-02-26", "2013-02-27", "2013-02-28", "2013-03-01", "2013-03-02", "2013-03-03", "2013-03-04", "2013-03-05", "2013-03-06", "2013-03-07", "2013-03-08", "2013-03-09", "2013-03-10", "2013-03-11", "2013-03-12", "2013-03-13", "2013-03-14", "2013-03-15", "2013-03- ...

# %%
## Feature Engineering

# Deriving rolling Columns
def rollingColumns(df, groupbyCol, column, shiftNum, period):
    df[column+'_'+str(period)+'day_median'] = df.groupby(groupbyCol)[[column]].shift(
        shiftNum).rolling(period, min_periods=1).median().reset_index(0, drop=True)
    df[column+'_'+str(period)+'day_mean'] = df.groupby(groupbyCol)[[column]].shift(
        shiftNum).rolling(period, min_periods=1).mean().reset_index(0, drop=True)
    df[column+'_'+str(period)+'day_std'] = df.groupby(groupbyCol)[[column]].shift(
        shiftNum).rolling(period, min_periods=1).std().reset_index(0, drop=True)
    df[column+'_'+str(period)+'day_min'] = df.groupby(groupbyCol)[[column]].shift(
        shiftNum).rolling(period, min_periods=1).min().reset_index(0, drop=True)
    df[column+'_'+str(period)+'day_max'] = df.groupby(groupbyCol)[[column]].shift(
        shiftNum).rolling(period, min_periods=1).max().reset_index(0, drop=True)
    return df

# Deriving lag columns
def lagColumns(df, column, num):
    df[column+"_lag"+str(num)] = df.groupby('Store')[[column]].shift(num)
    return df

# Deriving diff Columns of the first lag
def diffColumns(df, column, num):
    df[column+"_diff"+str(num)] = df.groupby('Store')[[column]].shift(1).diff(num)
    return df

# %%
# Autocorrelation of the target feature

sm.tsa.graphics.plot_acf(df_sales['Sales'], lags=50)

# %%
# Target Derived Columns

# Moving Averages based 
mvPeriods = [7, 14, 21, 28]
for i in mvPeriods:
    df_sales = rollingColumns(df_sales, 'Store', 'Sales', 1, i)
    
# Lags 
lagPeriods = [1, 2, 3, 4, 5, 6, 7]
for i in lagPeriods:
    df_sales = lagColumns(df_sales, 'Sales', i)

# Diff columns
df_sales = diffColumns(df_sales, 'Sales', 1)

# %%
# Target derived columns

targetCols = [col for col in df_sales.columns if "Sales" in col]
df_sales[targetCols].head(10)
# Out:
#       Sales  Sales_7day_median  Sales_7day_mean  Sales_7day_std  \
# 0  76819.40                NaN              NaN             NaN
# 1  78963.86           76819.40     76819.400000             NaN
# 2  74824.71           77891.63     77891.630000     1516.362208
# 3  78523.92           76819.40     76869.323333     2070.026554
# 4  76445.90           77671.66     77282.972500     1881.779961
# 5  85096.96           76819.40     77115.558000     1672.112419
# 6  86807.56           77671.66     78445.791667     3585.233270
# 7  78133.71           78523.92     79640.330000     4549.729019
# 8  74186.36           78523.92     79828.088571     4439.701372
# 9  73390.55           78133.71     79145.588571     4934.356698
#
#    Sales_7day_min  Sales_7day_max  Sales_14day_median  Sales_14day_mean  \
# 0             NaN             NaN                 NaN               NaN
# 1        76819.40        76819.40           76819.400      76819.400000
# 2        76819.40        78963.86           77891.630      77891.630000
# 3        74824.71        78963.86           76819.400      76869.323333
# 4        74824.71        78963.86           77671.660      77282.972500
# 5        74824.71        78963.86           76819.400      77115.558000
# 6        74824.71        85096.96           77671.660      78445.791667
# 7        74824.71        86807.56           78523.920      79640.330000
# 8        74824.71        86807.56           78328.815      79452.002500
# 9        74186.36        86807.56           78133.710      78866.931111
#
#    Sales_14day_std  Sales_14day_min  ...  Sales_28day_min  Sales_28day_max  \
# 0              NaN              NaN  ...              NaN              NaN
# 1              NaN         76819.40  ...         76819.40         76819.40
# 2      1516.362208         76819.40  ...         76819.40         78963.86
# 3      2070.026554         74824.71  ...         74824.71         78963.86
# 4      1881.779961         74824.71  ...         74824.71         78963.86
# 5      1672.112419         74824.71  ...         74824.71         78963.86
# 6      3585.233270         74824.71  ...         74824.71         85096.96
# 7      4549.729019         74824.71  ...         74824.71         86807.56
# 8      4245.777242         74824.71  ...         74824.71         86807.56
# 9      4342.127717         74186.36  ...         74186.36         86807.56
#
#    Sales_lag1  Sales_lag2  Sales_lag3  Sales_lag4  Sales_lag5  Sales_lag6  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1    76819.40         NaN         NaN         NaN         NaN         NaN
# 2    78963.86    76819.40         NaN         NaN         NaN         NaN
# 3    74824.71    78963.86    76819.40         NaN         NaN         NaN
# 4    78523.92    74824.71    78963.86    76819.40         NaN         NaN
# 5    76445.90    78523.92    74824.71    78963.86    76819.40         NaN
# 6    85096.96    76445.90    78523.92    74824.71    78963.86    76819.40
# 7    86807.56    85096.96    76445.90    78523.92    74824.71    78963.86
# 8    78133.71    86807.56    85096.96    76445.90    78523.92    74824.71
# 9    74186.36    78133.71    86807.56    85096.96    76445.90    78523.92
#
#    Sales_lag7  Sales_diff1
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN      2144.46
# 3         NaN     -4139.15
# 4         NaN      3699.21
# 5         NaN     -2078.02
# 6         NaN      8651.06
# 7    76819.40      1710.60
# 8    78963.86     -8673.85
# 9    74824.71     -3947.35
#
# [10 rows x 29 columns]

# %%
# Calculating Moving averages for quantitative features

quantitativeCols = ['Store_Size', 'Num_Employees', 'Returns_Pct', 'Num_Customers', 'Pct_On_Sale', 'Pct_Promotional']

for col in quantitativeCols:
    for i in mvPeriods:
        df_sales = rollingColumns(df_sales, 'Store', col, 1, i)

# %%
# Calculating lags for quantitative features

for col in quantitativeCols:
    for i in lagPeriods:
        df_sales = lagColumns(df_sales, col, i)

# %%
# Calculating diff columns for quantitative features

for col in quantitativeCols:
        df_sales = diffColumns(df_sales, col, 1)

# %%
# One-Hot encoding for 'Store'

df_sales[list(pd.get_dummies(df_sales.Store).columns)] = pd.get_dummies(df_sales.Store)

# %%
# Converting features 'Holiday' and 'DestinationEvent' to numerical

df_sales['Holiday'] = np.where(df_sales['Holiday'] == 'Yes', 1, 0)
df_sales['DestinationEvent'] = np.where(df_sales['DestinationEvent'] == 'Yes', 1, 0)

# %%
## Preprocessing the text data for feature 'Marketing'

# Using regex to filter the non alphabet/numeric characters
stopWords =  stopwords.words('english')
df_sales.Marketing = [re.sub('[^a-zA-Z]', ' ', text) for text in df_sales.Marketing]

# Converting description to lowercase
df_sales.Marketing = [text.lower() for text in df_sales.Marketing]
# Spliting the description to words
df_sales.Marketing = [text.split() for text in df_sales.Marketing]
# Removing the stopwords
df_sales.Marketing = [[word for word in text if word not in stopWords] for text in df_sales.Marketing]
# Stemming the words and joining them to sentence 
pStem = PorterStemmer()
df_sales.Marketing = [" ".join([pStem.stem(word) for word in text]) for text in df_sales.Marketing]

# %%
# Using tfidf vectorizer to extract vectors from text

tfidfVec = TfidfVectorizer(max_features=100, lowercase=True, analyzer='word', ngram_range=(1,1), max_df=0.85)
tfidfVec.fit(df_sales.Marketing)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.85, max_features=100, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
# Taking the length of text feature 'Marketing'

df_sales['MarketingLen'] = [len(text) for text in df_sales['Marketing']]

# %%
# Using Forward filling to minimize nan values for the economic indicator features

df_sales['Econ_ChangeGDP'] = df_sales['Econ_ChangeGDP'].fillna(method='ffill')
df_sales['EconJobsChange'] = df_sales['EconJobsChange'].fillna(method='ffill')
df_sales['AnnualizedCPI'] = df_sales['AnnualizedCPI'].fillna(method='ffill')

# %%
# Dropping the quantitative features 

df_sales.drop(quantitativeCols, axis=1, inplace=True)

# %%
# Printing the shape of dataframe

df_sales.shape
# Out:
# (7140, 225)

# %%
# Dividing the data into train and test

train, test = df_sales[df_sales.Date < '2014-01-01'], df_sales[df_sales.Date >= '2014-01-01']

train.shape, test.shape
# Out:
# ((5490, 225), (1650, 225))

# %%
train.groupby('Store')[['Sales']].count()
# Out:
#               Sales
# Store
# Baltimore       549
# Columbus        549
# Detroit         549
# Lancaster       549
# Louisville      549
# Philadelphia    549
# Portland        549
# Richmond        549
# San Antonio     549
# Savannah        549

# %%
test.groupby('Store')[['Sales']].count()
# Out:
#               Sales
# Store
# Baltimore       165
# Columbus        165
# Detroit         165
# Lancaster       165
# Louisville      165
# Philadelphia    165
# Portland        165
# Richmond        165
# San Antonio     165
# Savannah        165

# %%
# Dividing features and target for both train and test datasets

X_train, Y_train = train.drop('Sales', axis=1), train.Sales
X_test, Y_test = test.drop('Sales', axis=1), test.Sales

# %%
# Creating tf-idf vectors for train data

X_trainVect = tfidfVec.transform(X_train.Marketing)
X_train[pd.DataFrame(X_trainVect.toarray()).columns] = pd.DataFrame(X_trainVect.toarray())

# %%
# Creating tf-idf vectors for test data

X_testVect = tfidfVec.transform(X_test.Marketing)
X_test[pd.DataFrame(X_testVect.toarray()).columns] = pd.DataFrame(X_testVect.toarray())

# %%
# Droping columns 'Date', 'Store' and 'Marketing'

X_train.drop(['Date','Store','Marketing'], axis=1, inplace=True)
X_test.drop(['Date','Store','Marketing'], axis=1, inplace=True)

# %%
# Printing the shapes

X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((5490, 279), (5490,), (1650, 279), (1650,))

# %%
# Normalizing the train data

scaler = preprocessing.MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train.fillna(0))

# %%
# Basline Model - Linear Regression

modelLR = LinearRegression()
modelLR.fit(X_train_scaled, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model = XGBRegressor(max_depth=5, learning_rate=0.05, n_estimators=100, n_jobs=-1)
model.fit(X_train_scaled, Y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.05, max_delta_step=0,
#        max_depth=5, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
# Normalizing test data

X_test_scaled = scaler.transform(X_test.fillna(0))

# %%
# Prediction on test data using Linear Regression

y_pred_lr = modelLR.predict(X_test_scaled)

# %%
res = (Y_test-y_pred)

# %%
## Evaluation Metrics 

# Variance Score
print("Explained Variance of Linear Regression Model: " + str(metrics.explained_variance_score(Y_test, y_pred_lr)))

# RMSE
print("RMSE of Linear Regression Model: " + str(np.sqrt(metrics.mean_squared_error(Y_test, y_pred_lr))))
# Out:
# Explained Variance of Linear Regression Model: 0.430353975354526
# RMSE of Linear Regression Model: 16627.85793384853

# %%
# Prediction on test data using XGBoost

y_pred = model.predict(X_test_scaled)

# %%
## Evaluation Metrics 

# Variance Score

metrics.explained_variance_score(Y_test, y_pred)
# Out:
# 0.8735445338096172

# %%
# RMSE

np.sqrt(metrics.mean_squared_error(Y_test, y_pred))
# Out:
# 6956.573175362787

# %%
# Plotting feature importance

df_featImp = pd.DataFrame({'features': X_train.columns, 'importance': model.feature_importances_})
df_featImp = df_featImp.sort_values('importance').reset_index(drop=True).tail(15)

plt.figure()
df_featImp.plot(kind='barh', x='features', y='importance', legend=False, figsize=(15, 8))

# %%
df_featImp.sort_values('importance', ascending=False).reset_index(drop=True).head(15)
# Out:
#                features  importance
# 0             dayOfWeek    0.053348
# 1             Near_Xmas    0.033674
# 2            Sales_lag7    0.033295
# 3               Holiday    0.029134
# 4      Near_BlackFriday    0.028755
# 5     Sales_7day_median    0.025728
# 6            Sales_lag1    0.025350
# 7             dayOfYear    0.024215
# 8   Num_Customers_diff1    0.023837
# 9    Num_Customers_lag7    0.021945
# 10     DestinationEvent    0.021188
# 11   Num_Employees_lag7    0.018540
# 12      Store_Size_lag1    0.017783
# 13   Num_Customers_lag6    0.017026
# 14                  day    0.017026

# %%
# Plotting actual vs prediction for XGBoost

df_plot = test[['Store','Date','Sales']]
df_plot['Prediction'] = y_pred

# %%
# Plotting Batch predictions of sales for different stores over time.

data = [dict(
  type = 'scatter',
  name = 'Actual',
  x = df_plot.Date,
  y = df_plot.Sales,
  mode = 'markers+lines',
  transforms = [dict(
    type = 'groupby',
    groups = df_plot.Store
  )]
),
       dict(
  type = 'scatter',
  name = 'Prediction',
  x = df_plot.Date,
  y = df_plot.Prediction,
  mode = 'markers+lines',
  line = dict(color=['rgb(93, 164, 214)', 'rgb(255, 144, 14)',
               'rgb(44, 160, 101)', 'rgb(255, 65, 54)']),
  transforms = [dict(
    type = 'groupby',
    groups = df_plot.Store
  )]
)]


layout = {
    'title': 'Actual vs Prediction Sales Across locations',
    'yaxis': {'title': 'Sales'},
    'xaxis': {'title': 'Date'}
}


py.iplot({'data': data, 'layout': layout}, validate=False)
# Out:
# <div id="0fa13f86-a172-40be-a2e7-ef4c4b74f916" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0fa13f86-a172-40be-a2e7-ef4c4b74f916", [{"type": "scatter", "name": "Actual", "x": ["2014-01-01", "2014-01-02", "2014-01-03", "2014-01-04", "2014-01-05", "2014-01-06", "2014-01-07", "2014-01-08", "2014-01-09", "2014-01-10", "2014-01-11", "2014-01-12", "2014-01-13", "2014-01-14", "2014-01-15", "2014-01-16", "2014-01-17", "2014-01-18", "2014-01-19", "2014-01-20", "2014-01-21", "2014-01-22", "2014-01-23", "2014-01-24", "2014-01-25", "2014-01-26", "2014-01-27", "2014-01-28", "2014-01-29", "2014-01-30", "2014-01-31", "2014-02-01", "2014-02-02", "2014-02-03", "2014-02-04", "2014-02-05", "2014-02-06", "2014-02-07", "2014-02-08", "2014-02-09", "2014-02-10", "2014-02-11", "2014-02-12", "2014-02-13", "2014-02-14", "2014-02-15", "2014-02-16", "2014-02-17", "2014-02-18", "2014-02-19", "2014-02-20", "2014-02-21", "2014-02-22", "2014-02-23", "2014-02-24", "2014-02-25", "2014-02-26", "2014-02-27", "2014-02-28", "2014-03-01", "2014-03-02", "2014-03-03", "2014-03-04", "2014-03-05", "2014-03-06", "2014-03-07", "2014-03-08", "2014-03-09", "2014-03-10", "2014-03-11", "2014-03-12", "2014-03-13", "2014-03-14", "2014-03-15", "2014-03-16", "2014-03-17", "2014-03-18", "2014-03-19", "2014-03-20", "2014-03-21", "2014-03-22", "2014-03-23", "2014-03-24", "2014-03-25", "2014-03-26", "2014-03-27", "2014-03-28", "2014-03-29", "2014-03-30", "2014-03-31", "2014-04-01", "2014-04-02", "2014-04-03", "2014-04-04", "2014-04-05", "2014-04-06", "2014-04-07", "2014-04-08", "2014-04-09", "2014-04-10", "2014-04-11", "2014-04-12", "2014-04-13", "2014-04-14", "2014-04-15", "2014-04-16", "2014-04-17", "2014-04-18", "2014-04-19", "2014-04-20", "2014-04-21", "2014-04-22", "2014-04-23", "2014-04-24", "2014-04-25", "2014-04-26", "2014-04-27", "2014-04-28", "2014-04-29", "2014-04-30", "2014-05-01", "2014-05-02", "2014-05-03", "2014-05-04", "2014-05-05", "2014-05-06", "2014-05-07", "2014-05-08", "2014-05-09", "2014-05-10", "2014-05-11", "2014-05-12", "2014-05-13", "2014-05-14", "2014-05-15", "2014-05-16", "2014-05-17", "2014-05-18", "2014-05-19", "2014-05-20", "2014-05-21", "2014-05-22", "2014-05-23", "2014-05-24", "2014-05-25", "2014-05-26", "2014-05-27", "2014-05-28", "2014-05-29", "2014-05-30", "2014-05-31", "2014-06-01", "2014-06-02", "2014-06-03", "2014-06-04", "2014-06-05", "2014-06-06", "2014-06-07", "2014-06-08", "2014-06-09", "2014-06-10", "2014-06-11", "2014-06-12", "2014-06-13", "2014-06-14", "2014-01-01", "2014-01-02", "2014-01-03", "2014-01-04", "2014-01-05", "2014-01-06", "2014-01-07", "2014-01-08", "2014-01-09", "2014-01-10", "2014-01-11", "2014-01-12", "2014-01-13", "2014-01-14", "2014-01-15", "2014-01-16", "2014-01-17", "2014-01-18", "2014-01-19", "2014-01-20", "2014-01-21", "2014-01-22", "2014-01-23", "2014-01-24", "2014-01-25", "2014-01-26", "2014-01-27", "2014-01-28", "2014-01-29", "2014-01-30", "2014-01-31", "2014-02-01", "2014-02-02", "2014-02-03", "2014-02-04", "2014-02-05", "2014-02-06", "2014-02-07", "2014-02-08", "2014-02-09", "2014-02-10", "2014-02-11", "2014-02-12", "2014-02-13", "2014-02-14", "2014-02-15", "2014-02-16", "2014-02-17", "2014-02-18", "2014-02-19", "2014-02-20", "2014-02-21", "2014-02-22", "2014-02-23", "2014-02-24", "2014-02-25", "2014-02-26", "2014-02-27", "2014-02-28", "2014-03-01", "2014-03-02", "2014-03-03", "2014-03-04", "2014-03-05", "2014-03-06", "2014-03-07", "2014-03-08", "2014-03-09", "2014-03-10", "2014-03-11", "2014-03-12", "2014-03-13", "2014-03-14", "2014-03-15", "2014-03-16", "2014-03-17", "2014-03-18", "2014-03-19", "2014-03-20", "2014-03-21", "2014-03-22", "2014-03-23", "2014-03-24", "2014-03-25", "2014-03-26", "2014-03-27", "2014-03-28", "2014-03-29", "2014-03-30", "2014-03-31", "2014-04-01", "2014-04-02", "2014-04-03", "2014-04-04", "2014- ...

# %% [markdown]
# ### Walk Forward Validation

# %%
def walkForwardValidation(df, startDate, endDate):
    # Dividing the data into train and test
    train, test = df[df.Date < startDate], df[(df.Date >= startDate) & (df.Date < endDate)]
    # Dividing features and target for both train and test datasets
    X_train, Y_train = train.drop('Sales', axis=1), train.Sales
    X_test, Y_test = test.drop('Sales', axis=1), test.Sales
    # Creating tf-idf vectors for train data
    X_trainVect = tfidfVec.transform(X_train.Marketing)
    X_train[pd.DataFrame(X_trainVect.toarray()).columns] = pd.DataFrame(X_trainVect.toarray())
    # Creating tf-idf vectors for test data
    X_testVect = tfidfVec.transform(X_test.Marketing)
    X_test[pd.DataFrame(X_testVect.toarray()).columns] = pd.DataFrame(X_testVect.toarray())
    # Droping columns 'Date', 'Store' and 'Marketing'
    X_train.drop(['Date','Store','Marketing'], axis=1, inplace=True)
    X_test.drop(['Date','Store','Marketing'], axis=1, inplace=True)
    # Normalizing the train data
    scaler = preprocessing.MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train.fillna(0))
    # Fitting the Model
    model = XGBRegressor(max_depth=5, learning_rate=0.05, n_estimators=100, n_jobs=-1)
    model.fit(X_train_scaled, Y_train)
    # Normalizing test data
    X_test_scaled = scaler.transform(X_test.fillna(0))
    # Prediction on test data using XGBoost
    y_pred = model.predict(X_test_scaled)
    # Variance Score
    print("Variance: "+ str(metrics.explained_variance_score(Y_test, y_pred)))
    # RMSE
    print("RMSE: " + str(np.sqrt(metrics.mean_squared_error(Y_test, y_pred))))

# %%
startDate = pd.to_datetime('2014-01-01')
for i in range(6):
    print("Training Dataset End Date: " + str(startDate+relativedelta(months=i)))
    print("Testing Dataset Start Date: " + str(startDate+relativedelta(months=i+1)))
    walkForwardValidation(df_sales, startDate+relativedelta(months=i), startDate+relativedelta(months=i+1))
# Out:
# Training Dataset End Date: 2014-01-01 00:00:00
# Testing Dataset Start Date: 2014-02-01 00:00:00
# Vaiance: 0.9441605567764145
# RMSE: 6590.41647284326
# Training Dataset End Date: 2014-02-01 00:00:00
# Testing Dataset Start Date: 2014-03-01 00:00:00
# Vaiance: 0.9032904010360445
# RMSE: 7794.975324119923
# Training Dataset End Date: 2014-03-01 00:00:00
# Testing Dataset Start Date: 2014-04-01 00:00:00
# Vaiance: 0.7539958260187971
# RMSE: 5831.331055612217
# Training Dataset End Date: 2014-04-01 00:00:00
# Testing Dataset Start Date: 2014-05-01 00:00:00
# Vaiance: 0.582450737785516
# RMSE: 8259.084767724535
# Training Dataset End Date: 2014-05-01 00:00:00
# Testing Dataset Start Date: 2014-06-01 00:00:00
# Vaiance: 0.9451762411192955
# RMSE: 5393.430001095055
# Training Dataset End Date: 2014-06-01 00:00:00
# Testing Dataset Start Date: 2014-07-01 00:00:00
# Vaiance: 0.8931166004769971
# RMSE: 2967.521370173103
